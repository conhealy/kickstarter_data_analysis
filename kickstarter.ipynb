# %%
import pandas as pd
import numpy as np
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/conhealy/anaconda2/lib/python2.7/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['norm', 'cm']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
import simplejson

# %%
df = pd.read_csv('./data/final_file.csv')
# Out:
# /Users/conhealy/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (28,29,30,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df['state'].unique()
# Out:
# array(['failed', 'canceled', 'successful', 'live', 'suspended'], dtype=object)

# %%
df.columns
# Out:
# Index([u'id', u'photo', u'name', u'blurb', u'goal', u'pledged', u'state',
#        u'slug', u'disable_communication', u'country', u'currency',
#        u'currency_symbol', u'currency_trailing_code', u'deadline',
#        u'state_changed_at', u'created_at', u'launched_at', u'staff_pick',
#        u'backers_count', u'static_usd_rate', u'usd_pledged', u'creator',
#        u'location', u'category', u'profile', u'spotlight', u'urls',
#        u'source_url', u'friends', u'is_starred', u'is_backing',
#        u'permissions'],
#       dtype='object')

# %%
df['name'].head()
# Out:
# 0    Auntie Di's Music Time Sign ASL for Hearing an...
# 1                      Jump Start Kindergarten Toolkit
# 2    Ojukwu Balewa Awolowo (O.B.A.) Public Library ...
# 3        MASTIZE - [mas-TAHYZ, MAS-tahyz]  - to spread
# 4    Synopse der EU-DSGVO - Artikel, Erwägungsgründ...
# Name: name, dtype: object

# %%
df['blurb'][10]
# Out:
# 'Establishing a free, world-class, public library which will be a center  for curating and disseminating knowledge in Nigeria.'

# %%
df['goal'].head()
# Out:
# 0      1500.0
# 1       500.0
# 2    100000.0
# 3      5000.0
# 4      3222.0
# Name: goal, dtype: float64

# %%
df['pledged'].head()
# Out:
# 0      0.0
# 1      0.0
# 2    120.0
# 3      0.0
# 4    356.0
# Name: pledged, dtype: float64

# %%
df['slug'][10]
# Out:
# 'ojukwu-balewa-awolowo-oba-public-library-of-nigeri'

# %%
df['disable_communication'].head() # mostly false
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: disable_communication, dtype: bool

# %%
df['currency_trailing_code'].head() # true/false
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4    False
# Name: currency_trailing_code, dtype: bool

# %%
df['deadline'].head()
# Out:
# 0    1422030900
# 1    1430514802
# 2    1427375824
# 3    1412574077
# 4    1467046800
# Name: deadline, dtype: int64

# %%
df['staff_pick'].head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: staff_pick, dtype: bool

# %%
df['static_usd_rate'].head()
# Out:
# 0    1.000000
# 1    1.000000
# 2    1.000000
# 3    1.000000
# 4    1.114613
# Name: static_usd_rate, dtype: float64

# %%
df['creator'][0]
# Out:
# '{"urls":{"web":{"user":"https://www.kickstarter.com/profile/1469579873"},"api":{"user":"https://api.kickstarter.com/v1/users/1469579873?signature=1487286377.95b66530c95104f3039ad487fdfadbdd305ce1ff"}},"name":"Diana L. Smith","id":1469579873,"avatar":{"small":"https://ksr-ugc.imgix.net/assets/009/343/814/32fac3018ceff4216a223b1aefcd6a22_original.jpg?w=160&h=160&fit=crop&v=1461582891&auto=format&q=92&s=5bc913967f6d675be63d2eb43688b098","thumb":"https://ksr-ugc.imgix.net/assets/009/343/814/32fac3018ceff4216a223b1aefcd6a22_original.jpg?w=40&h=40&fit=crop&v=1461582891&auto=format&q=92&s=d3e80b6ffdf524b318a5a99891a813ff","medium":"https://ksr-ugc.imgix.net/assets/009/343/814/32fac3018ceff4216a223b1aefcd6a22_original.jpg?w=160&h=160&fit=crop&v=1461582891&auto=format&q=92&s=5bc913967f6d675be63d2eb43688b098"}}'

# %%
df['location'][0]
# Out:
# '{"country":"US","urls":{"web":{"discover":"https://www.kickstarter.com/discover/places/san-fernando-ca","location":"https://www.kickstarter.com/locations/san-fernando-ca"},"api":{"nearby_projects":"https://api.kickstarter.com/v1/discover?signature=1487284376.ff50d24c710d71bdaeada894f568435724a6c1c4&woe_id=2487952"}},"name":"San Fernando","displayable_name":"San Fernando, CA","short_name":"San Fernando, CA","id":2487952,"state":"CA","type":"Town","is_root":false,"slug":"san-fernando-ca"}'

# %%
df['category'][0]
# Out:
# '{"urls":{"web":{"discover":"http://www.kickstarter.com/discover/categories/publishing/academic"}},"color":14867664,"parent_id":18,"name":"Academic","id":323,"position":1,"slug":"publishing/academic"}'

# %%
df['profile'][0]
# Out:
# '{"background_image_opacity":0.8,"should_show_feature_image_section":true,"link_text_color":null,"state_changed_at":1425915885,"blurb":null,"background_color":null,"project_id":1546341,"name":null,"feature_image_attributes":{"image_urls":{"default":"https://ksr-ugc.imgix.net/assets/011/959/953/4e53aa51f82e9764b135307761da1cde_original.JPG?w=1552&h=873&fit=fill&bg=000000&v=1463719439&auto=format&q=92&s=70c684eaeb2b96fff3283fa72daeabee","baseball_card":"https://ksr-ugc.imgix.net/assets/011/959/953/4e53aa51f82e9764b135307761da1cde_original.JPG?w=1552&h=873&fit=fill&bg=000000&v=1463719439&auto=format&q=92&s=70c684eaeb2b96fff3283fa72daeabee"}},"link_url":null,"show_feature_image":false,"id":1546341,"state":"inactive","text_color":null,"link_text":null,"link_background_color":null}'

# %%
df['spotlight'].head() # mostly false
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: spotlight, dtype: bool

# %%
df['urls'][0]
# Out:
# '{"web":{"project":"https://www.kickstarter.com/projects/1469579873/auntie-dis-music-time-sign-asl-for-hearing-and-hoh?ref=category","rewards":"https://www.kickstarter.com/projects/1469579873/auntie-dis-music-time-sign-asl-for-hearing-and-hoh/rewards"}}'

# %%
df['source_url'][0]
# Out:
# 'https://www.kickstarter.com/discover/categories/publishing/academic?ref=category_modal&sort=magic'

# %%
df['friends'].head() # mostly NaN
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: friends, dtype: object

# %%
df['is_starred'].head() # mostly NaN
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: is_starred, dtype: object

# %%
df['is_backing'].head() # mostly NaN
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: is_backing, dtype: object

# %%
df['permissions'].head() # mostly NaN
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: permissions, dtype: object

# %%
def jsonParser(data):
  import json
  #print(data)
  if pd.isnull(data):
    #print("STop")
    return json.loads('{}')
  j1 = json.loads(data)
  return j1

# %%
to_df = pd.read_csv('./data/torontoData.csv', converters={'location':jsonParser}, header=0)
# Out:
# -----------------------------------------------------
# ValueError          Traceback (most recent call last)
# <ipython-input-163-acdee2543617> in <module>()
# ----> 1 to_df = pd.read_csv('./data/torontoData.csv', converters={'location':jsonParser}, header=0)
#
# ...

# %%
jsonParser('{"country":"CA","urls":{"web":{"discover":"https://www.kickstarter.com/discover/places/downtown-toronto-toronto-ca","location":"https://www.kickstarter.com/locations/downtown-toronto-toronto-ca"},"api":{"nearby_projects":"https://api.kickstarter.com/v1/discover?signature=1487284364.0e5100d680180cb55fb6094ff907ad73e777ac0e&woe_id=55855612"}},"name":"Downtown Toronto","displayable_name":"Downtown Toronto, Canada","short_name":"Downtown Toronto, Canada","id":55855612,"state":"ON","type":"Suburb","is_root":false,"slug":"downtown-toronto-toronto-ca"}')
# Out:
# {u'country': u'CA',
#  u'displayable_name': u'Downtown Toronto, Canada',
#  u'id': 55855612,
#  u'is_root': False,
#  u'name': u'Downtown Toronto',
#  u'short_name': u'Downtown Toronto, Canada',
#  u'slug': u'downtown-toronto-toronto-ca',
#  u'state': u'ON',
#  u'type': u'Suburb',
#  u'urls': {u'api': {u'nearby_projects': u'https://api.kickstarter.com/v1/discover?signature=1487284364.0e5100d680180cb55fb6094ff907ad73e777ac0e&woe_id=55855612'},
#   u'web': {u'discover': u'https://www.kickstarter.com/discover/places/downtown-toronto-toronto-ca',
#    u'location': u'https://www.kickstarter.com/locations/downtown-toronto-toronto-ca'}}}

# %%
'location':jsonParser, 'category':jsonParser, 'profile':jsonParser})

# %%
to_df["creator"]
# Out:
# ------------------------------------------------------------------------
# NameError                              Traceback (most recent call last)
# <ipython-input-18-2d3d58620558> in <module>()
# ----> 1 to_df["creator"]
#
# NameError: name 'to_df' is not defined

# %%
creators_to_df
# Out:
# -----------------------------------------------------
# NameError           Traceback (most recent call last)
# <ipython-input-165-daa0aeba9888> in <module>()
# ----> 1 creators_to_df
#
# NameError: name 'creators_to_df' is not defined

# %%
df2["location"] = df2["location"].apply(lambda x : dict(eval(x)) )
#to_df["location"].apply(pd.Series)
# Out:
# -----------------------------------------------------
# NameError           Traceback (most recent call last)
# <ipython-input-166-1aa113b1f5b2> in <module>()
# ----> 1 df2["location"] = df2["location"].apply(lambda x : dict(eval(x)) )
#       2 #to_df["location"].apply(pd.Series)
#
# NameError: name 'df2' is not defined

# %%
df = pd.DataFrame({'a':[1,2,3], 'b':[{'c':1}, {'d':3}, {'c':5, 'd':6}]})

# %%
df
# Out:
#    a                   b
# 0  1           {u'c': 1}
# 1  2           {u'd': 3}
# 2  3  {u'c': 5, u'd': 6}

# %%
df['b'].apply(pd.Series)
# Out:
#      c    d
# 0  1.0  NaN
# 1  NaN  3.0
# 2  5.0  6.0

# %%
to_df.head
# Out:
# ------------------------------------------------------------------------
# NameError                              Traceback (most recent call last)
# <ipython-input-12-86ce060b80bf> in <module>()
# ----> 1 to_df.head
#
# NameError: name 'to_df' is not defined

# %%
df.head()
# Out:
#            id                                              photo  \
# 0  1454391034  {"small":"https://ksr-ugc.imgix.net/assets/011...
# 1  1655206086  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 2   311581827  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 3   859724515  {"small":"https://ksr-ugc.imgix.net/assets/011...
# 4  1613604977  {"small":"https://ksr-ugc.imgix.net/assets/012...
#
#                                                 name  \
# 0  Auntie Di's Music Time Sign ASL for Hearing an...
# 1                    Jump Start Kindergarten Toolkit
# 2  Ojukwu Balewa Awolowo (O.B.A.) Public Library ...
# 3      MASTIZE - [mas-TAHYZ, MAS-tahyz]  - to spread
# 4  Synopse der EU-DSGVO - Artikel, Erwägungsgründ...
#
#                                                blurb      goal  pledged  \
# 0  MTS ASL Curriculum Workbook is a reproducible ...    1500.0      0.0
# 1  This kit teaches how to print, correct an ugly...     500.0      0.0
# ...

# %% [markdown]
# ## Features to massage:
# * location
# * creator
# * category

# %%
import ast
from pandas.io.json import json_normalize

def only_dict(d):
    '''
    Convert json string representation of dictionary to a python dict
    '''
    #print(d)
    return ast.literal_eval(d)

def list_of_dicts(ld):
    '''
    Create a mapping of the tuples formed after 
    converting json strings of list to a python list   
    '''
    return dict([(list(d.values())[1], list(d.values())[0]) for d in ast.literal_eval(ld)])

#A = json_normalize(df['creator'].apply(only_dict).tolist()).add_prefix('creator.')
#B = json_normalize(df['columnB'].apply(list_of_dicts).tolist()).add_prefix('columnB.pos.')

# %%
A = json_normalize(df['creator'].apply(only_dict).tolist()).add_prefix('creator.')
#B = json_normalize(df['columnB'].apply(list_of_dicts).tolist()).add_prefix('columnB.pos.')

# %%
A.head()
# Out:
#                                creator.avatar.medium  \
# 0  https://ksr-ugc.imgix.net/assets/009/343/814/3...
# 1  https://ksr-ugc.imgix.net/assets/009/597/858/d...
# 2  https://ksr-ugc.imgix.net/assets/009/490/285/e...
# 3  https://ksr-ugc.imgix.net/assets/009/256/276/4...
# 4  https://ksr-ugc.imgix.net/assets/012/523/143/a...
#
#                                 creator.avatar.small  \
# 0  https://ksr-ugc.imgix.net/assets/009/343/814/3...
# 1  https://ksr-ugc.imgix.net/assets/009/597/858/d...
# 2  https://ksr-ugc.imgix.net/assets/009/490/285/e...
# 3  https://ksr-ugc.imgix.net/assets/009/256/276/4...
# 4  https://ksr-ugc.imgix.net/assets/012/523/143/a...
#
#                                 creator.avatar.thumb  creator.id  \
# 0  https://ksr-ugc.imgix.net/assets/009/343/814/3...  1469579873
# 1  https://ksr-ugc.imgix.net/assets/009/597/858/d...   469955675
# 2  https://ksr-ugc.imgix.net/assets/009/490/285/e...   843612324
# ...

# %%
B = json_normalize(df['category'].apply(only_dict).tolist()).add_prefix('category.')

# %%
B.head()
# Out:
#    category.color  category.id category.name  category.parent_id  \
# 0        14867664          323      Academic                  18
# 1        14867664          323      Academic                  18
# 2        14867664          323      Academic                  18
# 3        14867664          323      Academic                  18
# 4        14867664          323      Academic                  18
#
#    category.position        category.slug  \
# 0                  1  publishing/academic
# 1                  1  publishing/academic
# 2                  1  publishing/academic
# 3                  1  publishing/academic
# 4                  1  publishing/academic
#
#                           category.urls.web.discover
# 0  http://www.kickstarter.com/discover/categories...
# 1  http://www.kickstarter.com/discover/categories...
# 2  http://www.kickstarter.com/discover/categories...
# 3  http://www.kickstarter.com/discover/categories...
# ...

# %%
df[df['location']==""]
# Out:
# Empty DataFrame
# Columns: [id, photo, name, blurb, goal, pledged, state, slug, disable_communication, country, currency, currency_symbol, currency_trailing_code, deadline, state_changed_at, created_at, launched_at, staff_pick, backers_count, static_usd_rate, usd_pledged, creator, location, category, profile, spotlight, urls, source_url, friends, is_starred, is_backing, permissions]
# Index: []
#
# [0 rows x 32 columns]

# %%
C = json_normalize(df['location'].apply(jsonParser).tolist()).add_prefix('location.')

# %%
C.head()
# Out:
#   location.country location.displayable_name  location.id location.is_root  \
# 0               US          San Fernando, CA    2487952.0            False
# 1               US             Greenwood, IN    2414687.0            False
# 2               NG            Lagos, Nigeria    1398823.0            False
# 3               US               Branson, MO    2368233.0            False
# 4               DE         Ismaning, Germany     663756.0            False
#
#   location.name location.short_name         location.slug location.state  \
# 0  San Fernando    San Fernando, CA       san-fernando-ca             CA
# 1     Greenwood       Greenwood, IN  greenwood-johnson-in             IN
# 2         Lagos      Lagos, Nigeria              lagos-ng          Lagos
# 3       Branson         Branson, MO            branson-mo             MO
# 4      Ismaning   Ismaning, Germany           ismaning-de        Bavaria
#
#   location.type                  location.urls.api.nearby_projects  \
# ...

# %%
C.count()
# Out:
# location.country                     174462
# location.displayable_name            174462
# location.id                          174462
# location.is_root                     174462
# location.name                        174462
# location.short_name                  174462
# location.slug                        174045
# location.state                       174427
# location.type                        174462
# location.urls.api.nearby_projects    174462
# location.urls.web.discover           174462
# location.urls.web.location           174462
# dtype: int64

# %%
df2 = df.join(json_normalize(df['location'].apply(jsonParser).tolist()).add_prefix('location.'), how='left')

# %%
df_all = df2.join(json_normalize(df2['category'].apply(jsonParser).tolist()).add_prefix('category.'), how='left')

# %%
canadaData = df_all[df_all['country']=='CA']

# %%
df_all.count()
# Out:
# id                                   175093
# photo                                175093
# name                                 175092
# blurb                                175080
# goal                                 175093
# pledged                              175093
# state                                175093
# slug                                 175093
# disable_communication                175093
# country                              175093
# currency                             175093
# currency_symbol                      175093
# currency_trailing_code               175093
# deadline                             175093
# state_changed_at                     175093
# created_at                           175093
# launched_at                          175093
# staff_pick                           175093
# backers_count                        175093
# static_usd_rate                      175093
# usd_pledged                          175093
# ...

# %%
df.count()
# Out:
# id                        175093
# photo                     175093
# name                      175092
# blurb                     175080
# goal                      175093
# pledged                   175093
# state                     175093
# slug                      175093
# disable_communication     175093
# country                   175093
# currency                  175093
# currency_symbol           175093
# currency_trailing_code    175093
# deadline                  175093
# state_changed_at          175093
# created_at                175093
# launched_at               175093
# staff_pick                175093
# backers_count             175093
# static_usd_rate           175093
# usd_pledged               175093
# creator                   175093
# location                  174462
# category                  175093
# profile                   175093
# spotlight                 175093
# urls                      175093
# source_url                175093
# ...

# %%
canadaData.count()
# Out:
# id                                   7200
# photo                                7200
# name                                 7200
# blurb                                7200
# goal                                 7200
# pledged                              7200
# state                                7200
# slug                                 7200
# disable_communication                7200
# country                              7200
# currency                             7200
# currency_symbol                      7200
# currency_trailing_code               7200
# deadline                             7200
# state_changed_at                     7200
# created_at                           7200
# launched_at                          7200
# staff_pick                           7200
# backers_count                        7200
# static_usd_rate                      7200
# usd_pledged                          7200
# creator                              7200
# ...

# %%
canadaData[canadaData['category.name']=='Software'].count()
# Out:
# id                                   142
# photo                                142
# name                                 142
# blurb                                142
# goal                                 142
# pledged                              142
# state                                142
# slug                                 142
# disable_communication                142
# country                              142
# currency                             142
# currency_symbol                      142
# currency_trailing_code               142
# deadline                             142
# state_changed_at                     142
# created_at                           142
# launched_at                          142
# staff_pick                           142
# backers_count                        142
# static_usd_rate                      142
# usd_pledged                          142
# creator                              142
# location                             142
# ...

# %%
canadaData['category.name'].unique()
# Out:
# array([u'Academic', u'Places', u'Electronic Music', u'Classical Music',
#        u'Blues', u'Video Games', u'Thrillers', u'Shorts', u'Apps',
#        u'Hardware', u'Web', u'Gadgets', u'Festivals', u'Plays', u'Flight',
#        u'DIY Electronics', u'Spaces', u'Musical', u'Immersive',
#        u'Experimental', u'Wearables', u'Space Exploration', u'Sound',
#        u'Software', u'Robots', u'Makerspaces', u'Fabrication Tools',
#        u'Camera Equipment', u'Fiction', u'3D Printing', u'Young Adult',
#        u'Art Books', u'Zines', u'Translations', u"Children's Books",
#        u'Nonfiction', u'Radio & Podcasts', u'Poetry', u'Country & Folk',
#        u'Literary Journals', u'Periodicals', u'Hip-Hop', u'Rock',
#        u'Tabletop Games', u'Television', u'Calendars', u'Narrative Film',
#        u'Pop', u'Kids', u'Performances', u'Comic Books', u'Photobooks',
#        u'Anthologies', u'People', u'Nature', u'Fine Art', u'Animals',
# ...

# %%
canadaData['location.state'].unique()
# Out:
# array([u'Lima Metropolitan Area', u'AB', u'BC', u'MB', u'Canterbury',
#        u'ON', u'QC', u'Masovian', u'Daegu', u'Jiangsu', u'Troms Fylke',
#        u'NB', u'Yukon Territory', u'CA', u'NY', u'SA', u'Centre',
#        u'San Jose', u'SK', u'Dar es Salaam', u'Beograd', u'NL', u'NS',
#        u'IL', u'Jerusalem', u'Burgas', u'Guangdong', u'Tokyo Prefecture',
#        u'Hong Kong Island', u'Distrito Especial', u'PE',
#        u'Moscow Federal City', u'Odessa Oblast', u'England', u'Pomeranian',
#        u'Berlin', u'Shanghai', u'Taipei City', u'Stockholm', u'Zhejiang',
#        u'Sichuan', u'Samsun', u'Orissa', u'Taichung City', u'CT', u'Hubei',
#        u'Ile-de-France', u'Central Singapore', u'Shandong',
#        u'Leningrad Oblast', u'Tel Aviv', u'National Capital Region',
#        u'Catalonia', u'Saint Andrew', u'South-East',
#        u'Federal Capital Territory', u'Jharkhand', u'Toledo', u'Loreto',
#        u'NT', u'Mukono', u'Lapland', u'Dubai',
# ...

# %%
canadaData[canadaData['location.state']=='SK'].count()
# Out:
# id                                   78
# photo                                78
# name                                 78
# blurb                                78
# goal                                 78
# pledged                              78
# state                                78
# slug                                 78
# disable_communication                78
# country                              78
# currency                             78
# currency_symbol                      78
# currency_trailing_code               78
# deadline                             78
# state_changed_at                     78
# created_at                           78
# launched_at                          78
# staff_pick                           78
# backers_count                        78
# static_usd_rate                      78
# usd_pledged                          78
# creator                              78
# location                             78
# ...

# %%
print(testValues)
# Out:
# {'Ontario': 9.0, 'British Columbia': 2.0, 'Nova Scotia': 7.0, 'Alberta': 1.0, 'New Brunswick': 4.0, 'Newfoundland and Labrador': 5.0, 'Saskatchewan': 12.0, 'Prince Edward Island': 10.0, 'Quebec': 11.0, 'Manitoba': 3.0, 'Northwest Territories': 6.0, 'Nunavut': 8.0, 'Yukon': 13.0}

# %%
goalTotals = {}
goalTotals['Ontario'] = canadaData[canadaData['location.state']=='ON'][canadaData['state']=='successful']['goal'].sum()
goalTotals['British Columbia'] = canadaData[canadaData['location.state']=='BC'][canadaData['state']=='successful']['goal'].sum()
goalTotals['Nova Scotia'] = canadaData[canadaData['location.state']=='NS'][canadaData['state']=='successful']['goal'].sum()
goalTotals['Alberta'] = canadaData[canadaData['location.state']=='AB'][canadaData['state']=='successful']['goal'].sum()
goalTotals['New Brunswick'] = canadaData[canadaData['location.state']=='NB'][canadaData['state']=='successful']['goal'].sum()
goalTotals['Newfoundland and Labrador'] = canadaData[canadaData['location.state']=='NL'][canadaData['state']=='successful']['goal'].sum()
goalTotals['Saskatchewan'] = canadaData[canadaData['location.state']=='SK'][canadaData['state']=='successful']['goal'].sum()
goalTotals['Prince Edward Island'] = canadaData[canadaData['location.state']=='PE'][canadaData['state']=='successful']['goal'].sum()
goalTotals['Quebec'] = canadaData[canadaData['location.state']=='QC'][canadaData['state']=='successful']['goal'].sum()
goalTotals['Manitoba'] = canadaData[canadaData['location.state']=='MB'][canadaData['state']=='successful']['goal'].sum()
goalTotals['Northwest Territories'] = canadaData[canadaData['location.state']=='NT'][canadaData['state']=='successful']['goal'].sum()
goalTotals['Nunavut'] = canadaData[canadaData['location.state']=='NU'][canadaData['state']=='successful']['goal'].sum()
goalTotals['Yukon'] = canadaData[canadaData['location.state']=='YT'][canadaData['state']=='successful']['goal'].sum()
# Out:
# /Users/conhealy/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app
# /Users/conhealy/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   app.launch_new_instance()
# /Users/conhealy/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/conhealy/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/conhealy/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# ...

# %%
print(goalTotals)
# Out:
# {'British Columbia': 5197980.0, 'Newfoundland and Labrador': 92370.0, 'Saskatchewan': 142272.0, 'Prince Edward Island': 101650.0, 'Ontario': 9668459.0, 'Nova Scotia': 407773.0, 'Quebec': 4189654.0, 'Alberta': 1542078.0, 'Manitoba': 768616.0, 'Northwest Territories': 20000.0, 'New Brunswick': 100314.0, 'Nunavut': 0, 'Yukon': 0}

# %%
pledgedTotals = {}
pledgedTotals['Ontario'] = round(canadaData[canadaData['location.state']=='ON'][canadaData['state']=='successful']['pledged'].sum(), 0)
pledgedTotals['British Columbia'] = round(canadaData[canadaData['location.state']=='BC'][canadaData['state']=='successful']['pledged'].sum(), 0)
pledgedTotals['Nova Scotia'] = round(canadaData[canadaData['location.state']=='NS'][canadaData['state']=='successful']['pledged'].sum(), 0)
pledgedTotals['Alberta'] = round(canadaData[canadaData['location.state']=='AB'][canadaData['state']=='successful']['pledged'].sum(), 0)
pledgedTotals['New Brunswick'] = round(canadaData[canadaData['location.state']=='NB'][canadaData['state']=='successful']['pledged'].sum(), 0)
pledgedTotals['Newfoundland and Labrador'] = round(canadaData[canadaData['location.state']=='NL'][canadaData['state']=='successful']['pledged'].sum(), 0)
pledgedTotals['Saskatchewan'] = round(canadaData[canadaData['location.state']=='SK'][canadaData['state']=='successful']['pledged'].sum(), 0)
pledgedTotals['Prince Edward Island'] = round(canadaData[canadaData['location.state']=='PE'][canadaData['state']=='successful']['pledged'].sum(), 0)
pledgedTotals['Quebec'] = round(canadaData[canadaData['location.state']=='QC'][canadaData['state']=='successful']['pledged'].sum(), 0)
pledgedTotals['Manitoba'] = round(canadaData[canadaData['location.state']=='MB'][canadaData['state']=='successful']['pledged'].sum(), 0)
pledgedTotals['Northwest Territories'] = round(canadaData[canadaData['location.state']=='NT'][canadaData['state']=='successful']['pledged'].sum(), 0)
pledgedTotals['Nunavut'] = round(canadaData[canadaData['location.state']=='NU'][canadaData['state']=='successful']['pledged'].sum(), 0)
pledgedTotals['Yukon'] = round(canadaData[canadaData['location.state']=='YT'][canadaData['state']=='successful']['pledged'].sum(), 0)
# Out:
# /Users/conhealy/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app
# /Users/conhealy/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   app.launch_new_instance()
# /Users/conhealy/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/conhealy/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/conhealy/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# ...

# %%
print(pledgedTotals)
# Out:
# {'British Columbia': 10077761.0, 'Newfoundland and Labrador': 116639.0, 'Saskatchewan': 313845.0, 'Prince Edward Island': 120585.0, 'Ontario': 26589048.0, 'Nova Scotia': 579865.0, 'Quebec': 8472931.0, 'Alberta': 3584995.0, 'Manitoba': 2010865.0, 'Northwest Territories': 21517.0, 'New Brunswick': 373025.0, 'Nunavut': 0.0, 'Yukon': 0.0}

# %%
canadaData[canadaData['location.state']=='ON'][canadaData['state']=='successful']['pledged']
# Out:
# /Users/conhealy/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
# 361       187706.54
# 515         3941.00
# 534         4016.00
# 863        70715.20
# 1039         630.00
# 1196        5872.00
# 1311        8620.00
# 1601         780.00
# 1604         752.00
# 1645        5258.00
# 1819       10338.00
# 1875        3470.00
# 1911        1185.00
# 2021        2191.00
# 2113        5665.00
# 2116         605.00
# 2146        3730.00
# 2156        1400.00
# 2602       25930.00
# 2661        1150.00
# 2667        1806.00
# 2711        1005.00
# 2736        1287.00
# 2773        2700.00
# 2881        2500.00
# 2890        4395.00
# 3370       12129.00
# 3694        3377.00
# 3767        4000.00
# 4033         610.00
#             ...
# 167871    422390.65
# 167901     32145.00
# 167949       625.00
# 167976       515.00
# 167987      5500.00
# 168037      1030.00
# ...

# %%
def flatten(js):
    return pd.DataFrame(js).set_index('pos').squeeze()

# %%
df.location.apply(flatten)
# Out:
# ------------------------------------------------------------------------
# PandasError                            Traceback (most recent call last)
# <ipython-input-41-7625bf5a7b49> in <module>()
# ----> 1 df.location.apply(flatten)
#
# /Users/conhealy/anaconda2/lib/python2.7/site-packages/pandas/core/series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    2290             else:
#    2291                 values = self.asobject
# -> 2292                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2293
#    2294         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/src/inference.pyx in pandas.lib.map_infer (pandas/lib.c:66116)()
#
# <ipython-input-30-36c96cae8b97> in flatten(js)
#       1 def flatten(js):
# ----> 2     return pd.DataFrame(js).set_index('pos').squeeze()
#
# /Users/conhealy/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __init__(self, data, index, columns, dtype, copy)
# ...

# %%
ast.literal_eval('{"country":"US","urls":{"web":{"discover":"https://www.kickstarter.com/discover/places/san-fernando-ca","location":"https://www.kickstarter.com/locations/san-fernando-ca"},"api":{"nearby_projects":"https://api.kickstarter.com/v1/discover?signature=1487284376.ff50d24c710d71bdaeada894f568435724a6c1c4&woe_id=2487952"}},"name":"San Fernando","displayable_name":"San Fernando, CA","short_name":"San Fernando, CA","id":2487952,"state":"CA","type":"Town","is_root":false,"slug":"san-fernando-ca"}')
# Out:
# ------------------------------------------------------------------------
# PandasError                            Traceback (most recent call last)
# <ipython-input-40-9e472c32cb31> in <module>()
# ----> 1 flatten('{"country":"US","urls":{"web":{"discover":"https://www.kickstarter.com/discover/places/san-fernando-ca","location":"https://www.kickstarter.com/locations/san-fernando-ca"},"api":{"nearby_projects":"https://api.kickstarter.com/v1/discover?signature=1487284376.ff50d24c710d71bdaeada894f568435724a6c1c4&woe_id=2487952"}},"name":"San Fernando","displayable_name":"San Fernando, CA","short_name":"San Fernando, CA","id":2487952,"state":"CA","type":"Town","is_root":false,"slug":"san-fernando-ca"}')
#
# <ipython-input-30-36c96cae8b97> in flatten(js)
#       1 def flatten(js):
# ----> 2     return pd.DataFrame(js).set_index('pos').squeeze()
#
# /Users/conhealy/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __init__(self, data, index, columns, dtype, copy)
# ...

# %%
import shapefile
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.patches import Polygon
from matplotlib.collections import PatchCollection

# %%
testValues={'Alberta': 1.0,
 'British Columbia': 2.0,
 'Manitoba': 3.0,
 'New Brunswick': 4.0,
 'Newfoundland and Labrador': 5.0,
 'Northwest Territories': 6.0,
 'Nova Scotia': 7.0,
 'Nunavut': 8.0,
 'Ontario': 9.0,
 'Prince Edward Island': 10.0,
 'Quebec': 11.0,
 'Saskatchewan': 12.0,
 'Yukon': 13.0}

displayPoints = {'British Columbia':[-123.94050141,   52.72872135],
'Quebec':[-71.94113447,  53.11090014],
'Nunavut':[-93.5175253 ,  64.82974335],
'Prince Edward Island':[-63.39405071,  48.43339508],
'Saskatchewan':[-106.38625843,   51.21414373],
'Yukon':[-135.43293066,   62.08469335],
'Manitoba':[-97.83934881,  56.55191593],
'Ontario':[-84.60617656,  50.07018605],
'New Brunswick':[-69.6499075,   44.28717142],
'Northwest Territories':[-121.48501127,   65.25301626],
'Alberta':[-115.74015842 ,  56.23383086],
'Newfoundland and Labrador':[-58.73108752,  55.41404249],
'Nova Scotia':[-57.30687173,  44.87194801] }

# %%
values = pledgedTotals

sf = shapefile.Reader("Canada4/gpr_000b11a_e.shp")
recs    = sf.records()
shapes  = sf.shapes()
Nshp    = len(shapes)
cns     = []
for nshp in xrange(Nshp):
    cns.append(recs[nshp][1])
cns = array(cns)
cm    = get_cmap('Dark2')
cccol = cm(1.*arange(Nshp)/Nshp)
#   -- plot --
fig     = plt.figure(figsize=(20,15))
ax      = fig.add_subplot(111)

cmap = matplotlib.cm.get_cmap('seismic')
norm = matplotlib.colors.Normalize(min(values.values()), max(values.values()))
color_producer = matplotlib.cm.ScalarMappable(norm=norm, cmap=cmap)

# Change the province name passed as you iterate through provinces.
#rgba = color_producer.to_rgba(values['Manitoba'])
#PatchCollection(ptchs, facecolor=rgba, edgecolor='k', linewidths=.5)

maxVal = 26589048.0 #maxVal = values.values.max
maxCircleWidth = 15.0

for nshp in xrange(Nshp):
    ptchs   = []
    pts     = array(shapes[nshp].points)
    
    ptsNParray = np.array(pts)
    #centroid = np.mean(ptsNParray, axis=0)
    centroid=displayPoints[recs[nshp][2]]
    print(centroid)
    ax.text(centroid[0], centroid[1]+1.0, recs[nshp][4]+"\n$"+str(values[recs[nshp][2]]), ha='center', size=20)
    
    prt     = shapes[nshp].parts
    par     = list(prt) + [pts.shape[0]]
    for pij in xrange(len(prt)):
     ptchs.append(Polygon(pts[par[pij]:par[pij+1]]))
    
    # colouring provinces
    #rgba = color_producer.to_rgba(values[recs[nshp][2]])
    ax.add_collection(PatchCollection(ptchs,facecolor='white',edgecolor='y', linewidths=.5)) 
    
    circleWidth = ((values[recs[nshp][2]]/maxVal) / 3.14)*maxCircleWidth
    circle = plt.Circle((centroid[0], centroid[1]), circleWidth, fc='r')
    plt.gca().add_patch(circle)
    
    
    #print(recs[nshp])
    
ax.set_xlim(-160,-40)   # (-160,-40)
ax.set_ylim(40,90)  

color_producer.set_array(values.values)
#plt.colorbar(color_producer)

#ax.text(-97, 55, "hello", ha='center', size=20)
ax.add_image

plt.axis('scaled')
plt.show()
# Out:
# [-123.94050141, 52.72872135]
# [-71.94113447, 53.11090014]
# [-93.5175253, 64.82974335]
# [-63.39405071, 48.43339508]
# [-106.38625843, 51.21414373]
# [-135.43293066, 62.08469335]
# [-97.83934881, 56.55191593]
# [-84.60617656, 50.07018605]
# [-69.6499075, 44.28717142]
# [-121.48501127, 65.25301626]
# [-115.74015842, 56.23383086]
# [-58.73108752, 55.41404249]
# [-57.30687173, 44.87194801]

# %%
numTotals = {}
numTotals['Ontario'] = canadaData[canadaData['location.state']=='ON'][canadaData['state']=='successful']['pledged'].count()
numTotals['British Columbia'] = canadaData[canadaData['location.state']=='BC'][canadaData['state']=='successful']['pledged'].count()
numTotals['Nova Scotia'] = canadaData[canadaData['location.state']=='NS'][canadaData['state']=='successful']['pledged'].count()
numTotals['Alberta'] = canadaData[canadaData['location.state']=='AB'][canadaData['state']=='successful']['pledged'].count()
numTotals['New Brunswick'] = canadaData[canadaData['location.state']=='NB'][canadaData['state']=='successful']['pledged'].count()
numTotals['Newfoundland and Labrador'] = canadaData[canadaData['location.state']=='NL'][canadaData['state']=='successful']['pledged'].count()
numTotals['Saskatchewan'] = canadaData[canadaData['location.state']=='SK'][canadaData['state']=='successful']['pledged'].count()
numTotals['Prince Edward Island'] = canadaData[canadaData['location.state']=='PE'][canadaData['state']=='successful']['pledged'].count()
numTotals['Quebec'] = canadaData[canadaData['location.state']=='QC'][canadaData['state']=='successful']['pledged'].count()
numTotals['Manitoba'] = canadaData[canadaData['location.state']=='MB'][canadaData['state']=='successful']['pledged'].count()
numTotals['Northwest Territories'] = canadaData[canadaData['location.state']=='NT'][canadaData['state']=='successful']['pledged'].count()
numTotals['Nunavut'] = canadaData[canadaData['location.state']=='NU'][canadaData['state']=='successful']['pledged'].count()
numTotals['Yukon'] = canadaData[canadaData['location.state']=='YT'][canadaData['state']=='successful']['pledged'].count()
# Out:
# /Users/conhealy/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app
# /Users/conhealy/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   app.launch_new_instance()
# /Users/conhealy/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/conhealy/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/conhealy/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# ...

# %%
print(numTotals)
# Out:
# {'British Columbia': 439, 'Newfoundland and Labrador': 13, 'Saskatchewan': 24, 'Prince Edward Island': 9, 'Ontario': 981, 'Nova Scotia': 53, 'Quebec': 389, 'Alberta': 185, 'Manitoba': 83, 'Northwest Territories': 2, 'New Brunswick': 21, 'Nunavut': 0, 'Yukon': 0}

# %%
values = numTotals

sf = shapefile.Reader("Canada4/gpr_000b11a_e.shp")
recs    = sf.records()
shapes  = sf.shapes()
Nshp    = len(shapes)
cns     = []
for nshp in xrange(Nshp):
    cns.append(recs[nshp][1])
cns = array(cns)
cm    = get_cmap('Dark2')
cccol = cm(1.*arange(Nshp)/Nshp)
#   -- plot --
fig     = plt.figure(figsize=(20,15))
ax      = fig.add_subplot(111)

cmap = matplotlib.cm.get_cmap('seismic')
norm = matplotlib.colors.Normalize(min(values.values()), max(values.values()))
color_producer = matplotlib.cm.ScalarMappable(norm=norm, cmap=cmap)

# Change the province name passed as you iterate through provinces.
#rgba = color_producer.to_rgba(values['Manitoba'])
#PatchCollection(ptchs, facecolor=rgba, edgecolor='k', linewidths=.5)

maxVal = 981.0 #maxVal = values.values.max
maxCircleWidth = 15.0

for nshp in xrange(Nshp):
    ptchs   = []
    pts     = array(shapes[nshp].points)
    
    ptsNParray = np.array(pts)
    #centroid = np.mean(ptsNParray, axis=0)
    centroid=displayPoints[recs[nshp][2]]
    print(centroid)
    ax.text(centroid[0], centroid[1]+1.0, recs[nshp][4]+"\n"+str(values[recs[nshp][2]]), ha='center', size=20)
    
    prt     = shapes[nshp].parts
    par     = list(prt) + [pts.shape[0]]
    for pij in xrange(len(prt)):
     ptchs.append(Polygon(pts[par[pij]:par[pij+1]]))
    
    # colouring provinces
    #rgba = color_producer.to_rgba(values[recs[nshp][2]])
    ax.add_collection(PatchCollection(ptchs,facecolor='white',edgecolor='y', linewidths=.5)) 
    
    circleWidth = ((values[recs[nshp][2]]/maxVal) / 3.14)*maxCircleWidth
    circle = plt.Circle((centroid[0], centroid[1]), circleWidth, fc='r')
    plt.gca().add_patch(circle)
    
    
    print(circleWidth)
    print(recs[nshp])
    
ax.set_xlim(-160,-40)   # (-160,-40)
ax.set_ylim(40,90)  

color_producer.set_array(values.values)
#plt.colorbar(color_producer)

#ax.text(-97, 55, "hello", ha='center', size=20)
ax.add_image

plt.axis('scaled')
plt.show()
# Out:
# [-123.94050141, 52.72872135]
# 2.13775102748
# ['59', 'British Columbia / Colombie-Britannique', 'British Columbia', 'Colombie-Britannique', 'B.C.', 'C.-B.']
# [-71.94113447, 53.11090014]
# 1.8942714116
# ['24', 'Quebec / Qu\xe9bec', 'Quebec', 'Qu\xe9bec', 'Que.', 'Qc']
# [-93.5175253, 64.82974335]
# 0.0
# ['62', 'Nunavut', 'Nunavut', 'Nunavut', 'Nvt.', 'Nt']
# [-63.39405071, 48.43339508]
# 0.0438263308596
# ['11', 'Prince Edward Island / \xcele-du-Prince-\xc9douard', 'Prince Edward Island', '\xcele-du-Prince-\xc9douard', 'P.E.I.', '\xce.-P.-\xc9.']
# [-106.38625843, 51.21414373]
# 0.116870215626
# ['47', 'Saskatchewan', 'Saskatchewan', 'Saskatchewan', 'Sask.', 'Sask.']
# [-135.43293066, 62.08469335]
# 0.0
# ['60', 'Yukon', 'Yukon', 'Yukon', 'Y.T.', 'Yn']
# [-97.83934881, 56.55191593]
# 0.404176162372
# ['46', 'Manitoba', 'Manitoba', 'Manitoba', 'Man.', 'Man.']
# [-84.60617656, 50.07018605]
# 4.77707006369
# ['35', 'Ontario', 'Ontario', 'Ontario', 'Ont.', 'Ont.']
# ...

# %%
values = testValues

sf = shapefile.Reader("Canada4/gpr_000b11a_e.shp")
recs    = sf.records()
shapes  = sf.shapes()
Nshp    = len(shapes)
cns     = []
for nshp in xrange(Nshp):
    cns.append(recs[nshp][1])
cns = array(cns)
cm    = get_cmap('Dark2')
cccol = cm(1.*arange(Nshp)/Nshp)
#   -- plot --
fig     = plt.figure(figsize=(20,15))
ax      = fig.add_subplot(111)

cmap = matplotlib.cm.get_cmap('seismic')
norm = matplotlib.colors.Normalize(min(values.values()), max(values.values()))
color_producer = matplotlib.cm.ScalarMappable(norm=norm, cmap=cmap)

# Change the province name passed as you iterate through provinces.
#rgba = color_producer.to_rgba(values['Manitoba'])
#PatchCollection(ptchs, facecolor=rgba, edgecolor='k', linewidths=.5)

maxVal = 13.0 #maxVal = values.values.max
maxCircleWidth = 15.0

for nshp in xrange(Nshp):
    ptchs   = []
    pts     = array(shapes[nshp].points)
    
    ptsNParray = np.array(pts)
    #centroid = np.mean(ptsNParray, axis=0)
    centroid=displayPoints[recs[nshp][2]]
    print(centroid)
    ax.text(centroid[0], centroid[1], recs[nshp][4]+"\n"+str(values[recs[nshp][2]]), ha='center', size=20)
    
    prt     = shapes[nshp].parts
    par     = list(prt) + [pts.shape[0]]
    for pij in xrange(len(prt)):
     ptchs.append(Polygon(pts[par[pij]:par[pij+1]]))
    
    # colouring provinces
    #rgba = color_producer.to_rgba(values[recs[nshp][2]])
    ax.add_collection(PatchCollection(ptchs,facecolor='white',edgecolor='k', linewidths=.5)) 
    
    circleWidth = ((values[recs[nshp][2]]/maxVal) / 3.14)*maxCircleWidth
    circle = plt.Circle((centroid[0], centroid[1]), circleWidth, fc='y')
    plt.gca().add_patch(circle)
    
    
    #print(recs[nshp])
    
ax.set_xlim(-160,-40)   # (-160,-40)
ax.set_ylim(40,90)  

color_producer.set_array(values.values)
#plt.colorbar(color_producer)

#ax.text(-97, 55, "hello", ha='center', size=20)
ax.add_image

plt.axis('scaled')
plt.show()

# %%
populations = {}
populations['Ontario'] = 14094167
populations['British Columbia'] = 4777157
populations['Nova Scotia'] = 952024
populations['Alberta'] = 4280127
populations['New Brunswick'] = 757771
populations['Newfoundland and Labrador'] = 529696
populations['Saskatchewan'] = 1158339
populations['Prince Edward Island'] = 149383
populations['Quebec'] = 8356851
populations['Manitoba'] = 1328346
populations['Northwest Territories'] = 44263
populations['Nunavut'] = 37280
populations['Yukon'] = 37693

# %%
raisedPerCapita = {}
raisedPerCapita['Ontario'] = round(pledgedTotals['Ontario'] / populations['Ontario'], 2)
raisedPerCapita['British Columbia'] = round(pledgedTotals['British Columbia'] / populations['British Columbia'], 2)
raisedPerCapita['Nova Scotia'] = round(pledgedTotals['Nova Scotia'] / populations['Nova Scotia'], 2)
raisedPerCapita['Alberta'] = round(pledgedTotals['Alberta'] / populations['Alberta'], 2)
raisedPerCapita['New Brunswick'] = round(pledgedTotals['New Brunswick'] / populations['New Brunswick'], 2)
raisedPerCapita['Newfoundland and Labrador'] = round(pledgedTotals['Newfoundland and Labrador'] / populations['Newfoundland and Labrador'], 2)
raisedPerCapita['Saskatchewan'] = round(pledgedTotals['Saskatchewan'] / populations['Saskatchewan'], 2)
raisedPerCapita['Prince Edward Island'] = round(pledgedTotals['Prince Edward Island'] / populations['Prince Edward Island'], 2)
raisedPerCapita['Quebec'] = round(pledgedTotals['Quebec'] / populations['Quebec'], 2)
raisedPerCapita['Manitoba'] = round(pledgedTotals['Manitoba'] / populations['Manitoba'], 2)
raisedPerCapita['Northwest Territories'] = round(pledgedTotals['Northwest Territories'] / populations['Northwest Territories'], 2)
raisedPerCapita['Nunavut'] = round(pledgedTotals['Nunavut'] / populations['Nunavut'], 2)
raisedPerCapita['Yukon'] = round(pledgedTotals['Yukon'] / populations['Yukon'], 2)

# %%
raisedPerCapita
# Out:
# {'Alberta': 0.84,
#  'British Columbia': 2.11,
#  'Manitoba': 1.51,
#  'New Brunswick': 0.49,
#  'Newfoundland and Labrador': 0.22,
#  'Northwest Territories': 0.49,
#  'Nova Scotia': 0.61,
#  'Nunavut': 0.0,
#  'Ontario': 1.89,
#  'Prince Edward Island': 0.81,
#  'Quebec': 1.01,
#  'Saskatchewan': 0.27,
#  'Yukon': 0.0}

# %%
values = raisedPerCapita

sf = shapefile.Reader("Canada4/gpr_000b11a_e.shp")
recs    = sf.records()
shapes  = sf.shapes()
Nshp    = len(shapes)
cns     = []
for nshp in xrange(Nshp):
    cns.append(recs[nshp][1])
cns = array(cns)
cm    = get_cmap('Dark2')
cccol = cm(1.*arange(Nshp)/Nshp)
#   -- plot --
fig     = plt.figure(figsize=(20,15))
ax      = fig.add_subplot(111)

cmap = matplotlib.cm.get_cmap('seismic')
norm = matplotlib.colors.Normalize(min(values.values()), max(values.values()))
color_producer = matplotlib.cm.ScalarMappable(norm=norm, cmap=cmap)

# Change the province name passed as you iterate through provinces.
#rgba = color_producer.to_rgba(values['Manitoba'])
#PatchCollection(ptchs, facecolor=rgba, edgecolor='k', linewidths=.5)

maxVal = 2.2 #maxVal = values.values.max
maxCircleWidth = 15.0

for nshp in xrange(Nshp):
    ptchs   = []
    pts     = array(shapes[nshp].points)
    
    ptsNParray = np.array(pts)
    #centroid = np.mean(ptsNParray, axis=0)
    centroid=displayPoints[recs[nshp][2]]
    print(centroid)
    ax.text(centroid[0], centroid[1]+1.0, recs[nshp][4]+"\n$"+str(values[recs[nshp][2]]), ha='center', size=20)
    
    prt     = shapes[nshp].parts
    par     = list(prt) + [pts.shape[0]]
    for pij in xrange(len(prt)):
     ptchs.append(Polygon(pts[par[pij]:par[pij+1]]))
    
    # colouring provinces
    #rgba = color_producer.to_rgba(values[recs[nshp][2]])
    ax.add_collection(PatchCollection(ptchs,facecolor='white',edgecolor='y', linewidths=.5)) 
    
    circleWidth = ((values[recs[nshp][2]]/maxVal) / 3.14)*maxCircleWidth
    circle = plt.Circle((centroid[0], centroid[1]), circleWidth, fc='r')
    plt.gca().add_patch(circle)
    
    
    print(circleWidth)
    print(recs[nshp])
    
ax.set_xlim(-160,-40)   # (-160,-40)
ax.set_ylim(40,90)  

color_producer.set_array(values.values)
#plt.colorbar(color_producer)

#ax.text(-97, 55, "hello", ha='center', size=20)
ax.add_image

plt.axis('scaled')
plt.show()
# Out:
# [-123.94050141, 52.72872135]
# 4.58164447018
# ['59', 'British Columbia / Colombie-Britannique', 'British Columbia', 'Colombie-Britannique', 'B.C.', 'C.-B.']
# [-71.94113447, 53.11090014]
# 2.19310943833
# ['24', 'Quebec / Qu\xe9bec', 'Quebec', 'Qu\xe9bec', 'Que.', 'Qc']
# [-93.5175253, 64.82974335]
# 0.0
# ['62', 'Nunavut', 'Nunavut', 'Nunavut', 'Nvt.', 'Nt']
# [-63.39405071, 48.43339508]
# 1.75883034163
# ['11', 'Prince Edward Island / \xcele-du-Prince-\xc9douard', 'Prince Edward Island', '\xcele-du-Prince-\xc9douard', 'P.E.I.', '\xce.-P.-\xc9.']
# [-106.38625843, 51.21414373]
# 0.586276780544
# ['47', 'Saskatchewan', 'Saskatchewan', 'Saskatchewan', 'Sask.', 'Sask.']
# [-135.43293066, 62.08469335]
# 0.0
# ['60', 'Yukon', 'Yukon', 'Yukon', 'Y.T.', 'Yn']
# [-97.83934881, 56.55191593]
# 3.27880718008
# ['46', 'Manitoba', 'Manitoba', 'Manitoba', 'Man.', 'Man.']
# [-84.60617656, 50.07018605]
# 4.10393746381
# ['35', 'Ontario', 'Ontario', 'Ontario', 'Ont.', 'Ont.']
# ...

# %%
numFailed = {}
numFailed['Ontario'] = canadaData[canadaData['location.state']=='ON'][canadaData['state']=='failed']['id'].count()
numFailed['British Columbia'] = canadaData[canadaData['location.state']=='BC'][canadaData['state']=='failed']['id'].count()
numFailed['Nova Scotia'] = canadaData[canadaData['location.state']=='NS'][canadaData['state']=='failed']['id'].count()
numFailed['Alberta'] = canadaData[canadaData['location.state']=='AB'][canadaData['state']=='failed']['id'].count()
numFailed['New Brunswick'] = canadaData[canadaData['location.state']=='NB'][canadaData['state']=='failed']['id'].count()
numFailed['Newfoundland and Labrador'] = canadaData[canadaData['location.state']=='NL'][canadaData['state']=='failed']['id'].count()
numFailed['Saskatchewan'] = canadaData[canadaData['location.state']=='SK'][canadaData['state']=='failed']['id'].count()
numFailed['Prince Edward Island'] = canadaData[canadaData['location.state']=='PE'][canadaData['state']=='failed']['id'].count()
numFailed['Quebec'] = canadaData[canadaData['location.state']=='QC'][canadaData['state']=='failed']['id'].count()
numFailed['Manitoba'] = canadaData[canadaData['location.state']=='MB'][canadaData['state']=='failed']['id'].count()
numFailed['Northwest Territories'] = canadaData[canadaData['location.state']=='NT'][canadaData['state']=='failed']['id'].count()
numFailed['Nunavut'] = canadaData[canadaData['location.state']=='NU'][canadaData['state']=='failed']['id'].count()
numFailed['Yukon'] = canadaData[canadaData['location.state']=='YT'][canadaData['state']=='failed']['id'].count()

succesRate = {}
succesRate['Ontario'] = round(numTotals['Ontario']/float(numTotals['Ontario'] + numFailed['Ontario']), 2)
succesRate['British Columbia'] = round(numTotals['British Columbia']/float(numTotals['British Columbia'] + numFailed['British Columbia']), 2)
succesRate['Nova Scotia'] = round(numTotals['Nova Scotia']/float(numTotals['Nova Scotia'] + numFailed['Nova Scotia']), 2)
succesRate['Alberta'] = round(numTotals['Alberta']/float(numTotals['Alberta'] + numFailed['Alberta']), 2)
succesRate['New Brunswick'] = round(numTotals['New Brunswick']/float(numTotals['New Brunswick'] + numFailed['New Brunswick']), 2)
succesRate['Newfoundland and Labrador'] = round(numTotals['Newfoundland and Labrador']/float(numTotals['Newfoundland and Labrador'] + numFailed['Newfoundland and Labrador']), 2)
succesRate['Saskatchewan'] = round(numTotals['Saskatchewan']/float(numTotals['Saskatchewan'] + numFailed['Saskatchewan']), 2)
succesRate['Prince Edward Island'] = round(numTotals['Prince Edward Island']/float(numTotals['Prince Edward Island'] + numFailed['Prince Edward Island']), 2)
succesRate['Quebec'] = round(numTotals['Quebec']/float(numTotals['Quebec'] + numFailed['Quebec']), 2)
succesRate['Manitoba'] = round(numTotals['Manitoba']/float(numTotals['Manitoba'] + numFailed['Manitoba']), 2)
succesRate['Northwest Territories'] = round(numTotals['Northwest Territories']/float(numTotals['Northwest Territories'] + numFailed['Northwest Territories']), 2)
succesRate['Nunavut'] = round(numTotals['Nunavut']/float(numTotals['Nunavut'] + numFailed['Nunavut']), 2)
succesRate['Yukon'] = 0.0
# Out:
# /Users/conhealy/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app
# /Users/conhealy/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   app.launch_new_instance()
# /Users/conhealy/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/conhealy/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /Users/conhealy/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# ...

# %%
print(succesRate)
# Out:
# {'British Columbia': 0.4, 'Newfoundland and Labrador': 0.34, 'Saskatchewan': 0.35, 'Prince Edward Island': 0.29, 'Ontario': 0.39, 'Nova Scotia': 0.4, 'Quebec': 0.38, 'Alberta': 0.32, 'Manitoba': 0.34, 'Northwest Territories': 0.5, 'New Brunswick': 0.45, 'Nunavut': 0.0, 'Yukon': 0.0}

# %%
values = succesRate

sf = shapefile.Reader("Canada4/gpr_000b11a_e.shp")
recs    = sf.records()
shapes  = sf.shapes()
Nshp    = len(shapes)
cns     = []
for nshp in xrange(Nshp):
    cns.append(recs[nshp][1])
cns = array(cns)
cm    = get_cmap('Dark2')
cccol = cm(1.*arange(Nshp)/Nshp)
#   -- plot --
fig     = plt.figure(figsize=(20,15))
ax      = fig.add_subplot(111)

cmap = matplotlib.cm.get_cmap('seismic')
norm = matplotlib.colors.Normalize(min(values.values()), max(values.values()))
color_producer = matplotlib.cm.ScalarMappable(norm=norm, cmap=cmap)

# Change the province name passed as you iterate through provinces.
#rgba = color_producer.to_rgba(values['Manitoba'])
#PatchCollection(ptchs, facecolor=rgba, edgecolor='k', linewidths=.5)

maxVal = 0.5 #maxVal = values.values.max
maxCircleWidth = 15.0

for nshp in xrange(Nshp):
    ptchs   = []
    pts     = array(shapes[nshp].points)
    
    ptsNParray = np.array(pts)
    #centroid = np.mean(ptsNParray, axis=0)
    centroid=displayPoints[recs[nshp][2]]
    print(centroid)
    ax.text(centroid[0], centroid[1]+1.0, recs[nshp][4]+"\n"+str(int(values[recs[nshp][2]]*100))+'%', ha='center', size=20)
    
    prt     = shapes[nshp].parts
    par     = list(prt) + [pts.shape[0]]
    for pij in xrange(len(prt)):
     ptchs.append(Polygon(pts[par[pij]:par[pij+1]]))
    
    # colouring provinces
    #rgba = color_producer.to_rgba(values[recs[nshp][2]])
    ax.add_collection(PatchCollection(ptchs,facecolor='white',edgecolor='y', linewidths=.5)) 
    
    circleWidth = ((values[recs[nshp][2]]/maxVal) / 3.14)*maxCircleWidth
    circle = plt.Circle((centroid[0], centroid[1]), circleWidth, fc='r')
    plt.gca().add_patch(circle)
    
    
    print(circleWidth)
    print(recs[nshp])
    
ax.set_xlim(-160,-40)   # (-160,-40)
ax.set_ylim(40,90)  

color_producer.set_array(values.values)
#plt.colorbar(color_producer)

#ax.text(-97, 55, "hello", ha='center', size=20)
ax.add_image

plt.axis('scaled')
plt.show()
# Out:
# [-123.94050141, 52.72872135]
# 3.82165605096
# ['59', 'British Columbia / Colombie-Britannique', 'British Columbia', 'Colombie-Britannique', 'B.C.', 'C.-B.']
# [-71.94113447, 53.11090014]
# 3.63057324841
# ['24', 'Quebec / Qu\xe9bec', 'Quebec', 'Qu\xe9bec', 'Que.', 'Qc']
# [-93.5175253, 64.82974335]
# 0.0
# ['62', 'Nunavut', 'Nunavut', 'Nunavut', 'Nvt.', 'Nt']
# [-63.39405071, 48.43339508]
# 2.77070063694
# ['11', 'Prince Edward Island / \xcele-du-Prince-\xc9douard', 'Prince Edward Island', '\xcele-du-Prince-\xc9douard', 'P.E.I.', '\xce.-P.-\xc9.']
# [-106.38625843, 51.21414373]
# 3.34394904459
# ['47', 'Saskatchewan', 'Saskatchewan', 'Saskatchewan', 'Sask.', 'Sask.']
# [-135.43293066, 62.08469335]
# 0.0
# ['60', 'Yukon', 'Yukon', 'Yukon', 'Y.T.', 'Yn']
# [-97.83934881, 56.55191593]
# 3.24840764331
# ['46', 'Manitoba', 'Manitoba', 'Manitoba', 'Man.', 'Man.']
# [-84.60617656, 50.07018605]
# 3.72611464968
# ['35', 'Ontario', 'Ontario', 'Ontario', 'Ont.', 'Ont.']
# ...

# %%
canadaData[canadaData['location.state']=='ON'][canadaData['state']=='failed']['id'].count()
# Out:
# /Users/conhealy/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
# 1549

# %% [markdown]
# ### !ls Canada/

# %%
import gdal
#import geopandas
# Out:
# -----------------------------------------------------
# ImportError         Traceback (most recent call last)
# <ipython-input-1-6241470f7427> in <module>()
# ----> 1 import gdal
#       2 #import geopandas
#
# /Users/conhealy/anaconda2/lib/python2.7/site-packages/gdal.py in <module>()
#       1 # import osgeo.gdal as a convenience
# ----> 2 from osgeo.gdal import deprecation_warn
#       3 deprecation_warn('gdal')
#       4
#       5 from osgeo.gdal import *
#
# /Users/conhealy/anaconda2/lib/python2.7/site-packages/osgeo/__init__.py in <module>()
#      19                 fp.close()
#      20             return _mod
# ---> 21     _gdal = swig_import_helper()
#      22     del swig_import_helper
#      23 else:
#
# /Users/conhealy/anaconda2/lib/python2.7/site-packages/osgeo/__init__.py in swig_import_helper()
#      15         if fp is not None:
#      16             try:
# ---> 17                 _mod = imp.load_module('_gdal', fp, pathname, description)
# ...

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

#map = Basemap(llcrnrlon=-160,llcrnrlat=40,urcrnrlon=4.,urcrnrlat=43.,
#             resolution='i', projection='tmerc', lat_0 = 90, lon_0 = -40)
Basemap(llcrnrlon=-119, llcrnrlat=22, urcrnrlon=-64,
                               urcrnrlat=49, projection='lcc', lat_1=33, lat_2=45,
                               lon_0=-95)


map.drawmapboundary(fill_color='aqua')
map.fillcontinents(color='#ddaa66',lake_color='aqua')
map.drawcoastlines()

map.readshapefile('Canada/Canada', 'comarques')

plt.show()
# Out:
# -----------------------------------------------------
# ValueError          Traceback (most recent call last)
# <ipython-input-12-437918064bd3> in <module>()
#      13 map.drawcoastlines()
#      14
# ---> 15 map.readshapefile('Canada/Canada', 'comarques')
#      16
#      17 plt.show()
#
# /Users/conhealy/anaconda2/lib/python2.7/site-packages/mpl_toolkits/basemap/__init__.pyc in readshapefile(self, shapefile, name, drawbounds, zorder, linewidth, color, antialiased, ax, default_encoding)
#    2175                     lons, lats = list(zip(*verts[indx1:indx2]))
#    2176                     if max(lons) > 721. or min(lons) < -721. or max(lats) > 90.01 or min(lats) < -90.01:
# -> 2177                         raise ValueError(msg)
#    2178                     # if latitude is slightly greater than 90, truncate to 90
#    2179                     lats = [max(min(lat, 90.0), -90.0) for lat in lats]
#
# ...

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
# setup Lambert Conformal basemap.
m = Basemap(width=6000000,height=3000000,projection='lcc',
            resolution='c',lat_1=45.,lat_2=55,lat_0=50,lon_0=-107.)
# draw coastlines.
m.drawcoastlines()
# draw a boundary around the map, fill the background.
# this background will end up being the ocean color, since
# the continents will be drawn on top.
m.drawmapboundary(fill_color='aqua')
# fill continents, set lake color same as ocean color.
m.fillcontinents(color='coral',lake_color='aqua')

m.readshapefile('Canada3/can_ab_l_geo83_e', 'comarques')

plt.figure(figsize=(20,15))
plt.show()

# %%
canadaData['goal'].max()
# Out:
# 100000000.0

# %%
canadaData[canadaData['goal']==100000000.0]['creator'][132271]
# Out:
# '{"urls":{"web":{"user":"https://www.kickstarter.com/profile/1443949823"},"api":{"user":"https://api.kickstarter.com/v1/users/1443949823?signature=1487292430.e7453f756a194c945c909cb6825fae55b7def595"}},"name":"Steven Stanley Bayes","id":1443949823,"avatar":{"small":"https://ksr-ugc.imgix.net/assets/008/361/762/caf642e16f89e8936b0cca9242725091_original.jpg?w=160&h=160&fit=crop&v=1461519537&auto=format&q=92&s=e328355a7691870ccc15a953ca4b339d","thumb":"https://ksr-ugc.imgix.net/assets/008/361/762/caf642e16f89e8936b0cca9242725091_original.jpg?w=40&h=40&fit=crop&v=1461519537&auto=format&q=92&s=83c66458bde7336042afb5947caf2703","medium":"https://ksr-ugc.imgix.net/assets/008/361/762/caf642e16f89e8936b0cca9242725091_original.jpg?w=160&h=160&fit=crop&v=1461519537&auto=format&q=92&s=e328355a7691870ccc15a953ca4b339d"}}'

# %%
canadaData[canadaData['goal']==100000000.0]['blurb'][172520]
# Out:
# 'Fashion illustration as a portrait.'

# %%
canadaData['goal'].hist(range=(0.0,20000.0), bins=40)

# %%
canadaData[canadaData['state']=='failed']['goal'].hist(range=(0.0,10000.0), bins=20)

# %%
canadaData[canadaData['state']=='successful']['goal'].hist(range=(0.0,10000.0), bins=20)

# %%
canadaData['bin500'] = (floor(canadaData['goal']/500))*500.0 + 250
# Out:
# /Users/conhealy/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
canadaData['bin500']
# Out:
# 22          12250.0
# 32            250.0
# 64          94250.0
# 89           3250.0
# 119          2250.0
# 135          2250.0
# 181          1750.0
# 249         27250.0
# 269          5750.0
# 275           750.0
# 306          1250.0
# 358         40250.0
# 361         40250.0
# 395         40250.0
# 412          9250.0
# 428        500250.0
# 430         50250.0
# 439        300250.0
# 491          2750.0
# 515          3750.0
# 534          4250.0
# 644         15250.0
# 705         15250.0
# 711         35250.0
# 717        100250.0
# 726         80250.0
# 772          5250.0
# 775          4250.0
# 780         50250.0
# 783          5250.0
#             ...
# 173929        750.0
# 173939       5250.0
# 173946       5250.0
# 174082        750.0
# 174318       3250.0
# 174385    1800250.0
# 174475       3250.0
# 174479        750.0
# 174485       1250.0
# 174581      38250.0
# 174582       3750.0
# 174606        750.0
# 174663        250.0
# 174722      49750.0
# ...

# %%
failSeries = canadaData[canadaData['state'] =='failed' ].groupby('bin500').count()['id']

# %%
succSeries = canadaData[canadaData['state'] =='successful' ].groupby('bin500').count()['id']

# %%
succRate = succSeries/(failSeries + succSeries)

# %%
plt.scatter(succRate.index, succRate)

# %%
succRate.plot(xlim=(0.0,100.0), kind='bar')

# %%
succRate.iplot(kind='bar')
# Out:
# -----------------------------------------------------
# AttributeError      Traceback (most recent call last)
# <ipython-input-391-3b10e9cc9a9b> in <module>()
# ----> 1 succRate.iplot(kind='bar')
#
# /Users/conhealy/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'iplot'

# %%
tempDF = succRate.to_frame().reset_index()  #.plot(x='bin500', y='id', xlim=(0.0, 10000.0), kind='bar')

# %%
tempDF
# Out:
#           bin500        id
# 0          250.0  0.477454
# 1          750.0  0.504975
# 2         1250.0  0.474801
# 3         1750.0  0.493617
# 4         2250.0  0.444444
# 5         2750.0  0.432692
# 6         3250.0  0.444828
# 7         3750.0  0.459677
# 8         4250.0  0.503356
# 9         4750.0  0.546875
# 10        5250.0  0.370036
# 11        5750.0  0.365079
# 12        6250.0  0.403101
# 13        6750.0  0.584906
# 14        7250.0  0.321429
# 15        7750.0  0.506494
# 16        8250.0  0.336538
# 17        8750.0  0.487179
# 18        9250.0  0.416667
# 19        9750.0  0.413793
# 20       10250.0  0.349099
# 21       10750.0  0.636364
# 22       11250.0  0.413793
# 23       11750.0  0.625000
# 24       12250.0  0.531646
# 25       12750.0  0.347826
# 26       13250.0  0.350000
# 27       13750.0  0.400000
# 28       14250.0  0.529412
# 29       14750.0  0.333333
# ..           ...       ...
# 190     460250.0       NaN
# 191     480250.0       NaN
# ...

# %%
plotDF = tempDF[tempDF['bin500']<=20000]

# %%
plotDF
# Out:
#      bin500        id
# 0     250.0  0.477454
# 1     750.0  0.504975
# 2    1250.0  0.474801
# 3    1750.0  0.493617
# 4    2250.0  0.444444
# 5    2750.0  0.432692
# 6    3250.0  0.444828
# 7    3750.0  0.459677
# 8    4250.0  0.503356
# 9    4750.0  0.546875
# 10   5250.0  0.370036
# 11   5750.0  0.365079
# 12   6250.0  0.403101
# 13   6750.0  0.584906
# 14   7250.0  0.321429
# 15   7750.0  0.506494
# 16   8250.0  0.336538
# 17   8750.0  0.487179
# 18   9250.0  0.416667
# 19   9750.0  0.413793
# 20  10250.0  0.349099
# 21  10750.0  0.636364
# 22  11250.0  0.413793
# 23  11750.0  0.625000
# 24  12250.0  0.531646
# 25  12750.0  0.347826
# 26  13250.0  0.350000
# 27  13750.0  0.400000
# 28  14250.0  0.529412
# 29  14750.0  0.333333
# 30  15250.0  0.357759
# 31  15750.0  0.400000
# 32  16250.0  0.631579
# 33  16750.0  0.166667
# 34  17250.0  0.285714
# 35  17750.0  0.454545
# 36  18250.0  0.200000
# 37  18750.0  0.250000
# 38  19250.0  0.400000
# 39  19750.0  0.600000

# %%
fig, ax = plt.subplots(figsize=(10, 8))
#ax.plot(df1.date, df1.line1, label='line1', c='r')
#ax.plot(df1.date, df1.line2, label='line2', c='b')
ax2 = ax#.twinx()
ax2.set_ylabel('probability of success')
ax2.set_xlabel('goal value')
ax2.bar(plotDF.bin500, plotDF.id, width=450, alpha=0.1, color='g')
ax.legend(loc='best')
ax.set_xticks(ax.get_xticks()[::2])

# %%
canadaData['goal'].median()
# Out:
# 6000.0

# %%
canadaData[canadaData['state']=='successful']['goal'].median()
# Out:
# 4500.0

# %%
canadaData[canadaData['state']=='failed']['goal'].median()
# Out:
# 8000.0

# %%
canadaData[canadaData['state']=='successful']['goal'].mean()
# Out:
# 10109.857923497268

# %%
canadaData[canadaData['state']=='failed']['goal'].mean()
# Out:
# 100811.535218509

# %%
canadaData[canadaData['state']=='successful']['pledged'].sum()
# Out:
# 56002602.42999996

# %%
canadaData['created_at'].min()
# Out:
# 1375727118

# %%
canadaData['created_at'].max()
# Out:
# 1487102481

# %%
canadaData['id'].count()
# Out:
# 7200

# %%
canadaData[canadaData['state']=='failed'].count()
# Out:
# id                                   3890
# photo                                3890
# name                                 3890
# blurb                                3890
# goal                                 3890
# pledged                              3890
# state                                3890
# slug                                 3890
# disable_communication                3890
# country                              3890
# currency                             3890
# currency_symbol                      3890
# currency_trailing_code               3890
# deadline                             3890
# state_changed_at                     3890
# created_at                           3890
# launched_at                          3890
# staff_pick                           3890
# backers_count                        3890
# static_usd_rate                      3890
# usd_pledged                          3890
# creator                              3890
# ...

# %%
canadaData['location.state'].unique()
# Out:
# array([u'Lima Metropolitan Area', u'AB', u'BC', u'MB', u'Canterbury',
#        u'ON', u'QC', u'Masovian', u'Daegu', u'Jiangsu', u'Troms Fylke',
#        u'NB', u'Yukon Territory', u'CA', u'NY', u'SA', u'Centre',
#        u'San Jose', u'SK', u'Dar es Salaam', u'Beograd', u'NL', u'NS',
#        u'IL', u'Jerusalem', u'Burgas', u'Guangdong', u'Tokyo Prefecture',
#        u'Hong Kong Island', u'Distrito Especial', u'PE',
#        u'Moscow Federal City', u'Odessa Oblast', u'England', u'Pomeranian',
#        u'Berlin', u'Shanghai', u'Taipei City', u'Stockholm', u'Zhejiang',
#        u'Sichuan', u'Samsun', u'Orissa', u'Taichung City', u'CT', u'Hubei',
#        u'Ile-de-France', u'Central Singapore', u'Shandong',
#        u'Leningrad Oblast', u'Tel Aviv', u'National Capital Region',
#        u'Catalonia', u'Saint Andrew', u'South-East',
#        u'Federal Capital Territory', u'Jharkhand', u'Toledo', u'Loreto',
#        u'NT', u'Mukono', u'Lapland', u'Dubai',
# ...

# %%
numFailed.values()
# Out:
# [669, 25, 45, 22, 1549, 81, 626, 398, 159, 2, 26, 1, 0]

# %%
669+ 25+ 45+ 22+ 1549+ 81+ 626+ 398+ 159+ 2+ 26+ 1+ 0
# Out:
# 3603

# %%
numTotals.values()
# Out:
# [439, 13, 24, 9, 981, 53, 389, 185, 83, 2, 21, 0, 0]

# %%
439+ 13+ 24+ 9+ 981+ 53+ 389+ 185+ 83+ 2+ 21+ 0
# Out:
# 2199

# %%
3603+2199
# Out:
# 5802
